# %% [markdown]
# # Introduction to Data Science - Homework 4
# *COMP 5360 / MATH 4100, University of Utah, http://datasciencecourse.net/*
#
# Due: Friday, February 9, 11:59pm.
#
# In this homework you will download SLC air quality data and compute a moving average. Then you'll complete an A/B test comparing two ads.

# %% [markdown]
# ## Your Data
# Fill out the following information:
#
# *First Name:*   Aniket
# *Last Name:*   Patil
# *E-mail:*   aniket.patil@utah.edu
# *UID:*  u1144414

# %%
# imports and setup 
import pandas as pd
import scipy as sc
from scipy.stats import norm

import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10, 6)
plt.style.use('ggplot')

# %% [markdown]
# ## Part 1: SLC Air Quality Index
#
# In this problem, you'll study the Air Quality at Hawthorn Elementary School in Salt Lake City.
#
# ### Task 1.0.  Learn about AQI
#
# Read about air quality in SLC here: http://slcair.communication.utah.edu/
#
#
# ### Task 1.1. Download data
# The EPA gives access to air quality data on the AirData website. Become familiar with the cite by reading this [information page](https://www.epa.gov/outdoor-air-quality-data/air-data-basic-information).
#
#
# Go to [this website](https://www.epa.gov/outdoor-air-quality-data/download-daily-data) and download the following daily data:
# 1. Pollutant = PM2.5
# + Year = 2017
# + City = Salt Lake City, UT
# + Monitor Site = 490353006 (Hawthorn Elementary School)

# %% [markdown]
# ### Task 1.2. Import the data
# Use the pandas.read_csv() function to import the data
#
# A word of warning: this data isn't very clean:
#
# 1. The dates are not sorted.
# + some dates may have missing values.
# + some dates may have multiple values corresponding to different collection sites (POC=1,4,5).

# %%
# your code goes here
data=pd.read_csv('data.csv')
data.set_index('Date')
# Out:
#             AQS_SITE_ID  POC  Daily Mean PM2.5 Concentration     UNITS  \
# Date
# 01/05/2017    490353006    1                             5.4  ug/m3 LC
# 01/06/2017    490353006    1                            16.3  ug/m3 LC
# 01/07/2017    490353006    1                            36.5  ug/m3 LC
# 01/10/2017    490353006    1                             1.2  ug/m3 LC
# 01/11/2017    490353006    1                             2.4  ug/m3 LC
# 01/12/2017    490353006    1                            13.2  ug/m3 LC
# 01/13/2017    490353006    1                            18.3  ug/m3 LC
# 01/14/2017    490353006    1                            21.8  ug/m3 LC
# 01/15/2017    490353006    1                            18.4  ug/m3 LC
# 01/16/2017    490353006    1                            20.2  ug/m3 LC
# 01/17/2017    490353006    1                            28.9  ug/m3 LC
# 01/18/2017    490353006    1                            39.4  ug/m3 LC
# 01/19/2017    490353006    1                            38.5  ug/m3 LC
# 01/20/2017    490353006    1                            20.1  ug/m3 LC
# 01/21/2017    490353006    1                             7.1  ug/m3 LC
# 01/22/2017    490353006    1                             3.1  ug/m3 LC
# 01/23/2017    490353006    1                             2.0  ug/m3 LC
# 01/24/2017    490353006    1                             4.7  ug/m3 LC
# 01/25/2017    490353006    1                             4.6  ug/m3 LC
# 01/26/2017    490353006    1                             7.8  ug/m3 LC
# 01/27/2017    490353006    1                            13.4  ug/m3 LC
# 01/28/2017    490353006    1                            22.7  ug/m3 LC
# 01/29/2017    490353006    1                            32.8  ug/m3 LC
# 01/30/2017    490353006    1                            41.1  ug/m3 LC
# 01/31/2017    490353006    1                            45.5  ug/m3 LC
# 02/01/2017    490353006    1                            32.2  ug/m3 LC
# 02/02/2017    490353006    1                            42.2  ug/m3 LC
# 02/03/2017    490353006    1                            16.8  ug/m3 LC
# 02/04/2017    490353006    1                             3.3  ug/m3 LC
# 02/05/2017    490353006    1                             3.5  ug/m3 LC
# ...                 ...  ...                             ...       ...
# 12/02/2017    490353006    5                            19.7  ug/m3 LC
# 12/03/2017    490353006    5                             6.8  ug/m3 LC
# 12/04/2017    490353006    5                             2.7  ug/m3 LC
# 12/05/2017    490353006    5                             5.8  ug/m3 LC
# 12/06/2017    490353006    5                            10.3  ug/m3 LC
# 12/07/2017    490353006    5                             9.7  ug/m3 LC
# 12/08/2017    490353006    5                            18.3  ug/m3 LC
# 12/09/2017    490353006    5                            19.8  ug/m3 LC
# 12/10/2017    490353006    5                            25.1  ug/m3 LC
# 12/11/2017    490353006    5                            39.5  ug/m3 LC
# 12/12/2017    490353006    5                            59.0  ug/m3 LC
# 12/13/2017    490353006    5                            49.3  ug/m3 LC
# 12/14/2017    490353006    5                            21.9  ug/m3 LC
# 12/15/2017    490353006    5                            20.5  ug/m3 LC
# 12/16/2017    490353006    5                            18.3  ug/m3 LC
# 12/17/2017    490353006    5                             6.0  ug/m3 LC
# 12/18/2017    490353006    5                            11.7  ug/m3 LC
# 12/19/2017    490353006    5                            10.6  ug/m3 LC
# 12/20/2017    490353006    5                            10.3  ug/m3 LC
# 12/21/2017    490353006    5                             3.2  ug/m3 LC
# 12/22/2017    490353006    5                             8.6  ug/m3 LC
# 12/23/2017    490353006    5                             4.2  ug/m3 LC
# 12/24/2017    490353006    5                             7.1  ug/m3 LC
# 12/25/2017    490353006    5                            25.5  ug/m3 LC
# 12/26/2017    490353006    5                            25.0  ug/m3 LC
# 12/27/2017    490353006    5                            22.9  ug/m3 LC
# 12/28/2017    490353006    5                            24.0  ug/m3 LC
# 12/29/2017    490353006    5                            26.1  ug/m3 LC
# 12/30/2017    490353006    5                             9.1  ug/m3 LC
# 12/31/2017    490353006    5                            10.1  ug/m3 LC
#
#             DAILY_AQI_VALUE  DAILY_OBS_COUNT  PERCENT_COMPLETE  \
# Date
# 01/05/2017               23                1             100.0
# 01/06/2017               60                1             100.0
# 01/07/2017              103                1             100.0
# 01/10/2017                5                1             100.0
# 01/11/2017               10                1             100.0
# 01/12/2017               53                1             100.0
# 01/13/2017               64                1             100.0
# 01/14/2017               71                1             100.0
# 01/15/2017               64                1             100.0
# 01/16/2017               68                1             100.0
# 01/17/2017               86                1             100.0
# 01/18/2017              111                1             100.0
# 01/19/2017              108                1             100.0
# 01/20/2017               68                1             100.0
# 01/21/2017               30                1             100.0
# 01/22/2017               13                1             100.0
# 01/23/2017                8                1             100.0
# 01/24/2017               20                1             100.0
# 01/25/2017               19                1             100.0
# 01/26/2017               33                1             100.0
# 01/27/2017               54                1             100.0
# 01/28/2017               73                1             100.0
# 01/29/2017               95                1             100.0
# 01/30/2017              115                1             100.0
# 01/31/2017              126                1             100.0
# 02/01/2017               93                1             100.0
# 02/02/2017              117                1             100.0
# 02/03/2017               61                1             100.0
# 02/04/2017               14                1             100.0
# 02/05/2017               15                1             100.0
# ...                     ...              ...               ...
# 12/02/2017               67                1             100.0
# 12/03/2017               28                1             100.0
# 12/04/2017               11                1             100.0
# 12/05/2017               24                1             100.0
# 12/06/2017               43                1             100.0
# 12/07/2017               40                1             100.0
# 12/08/2017               64                1             100.0
# 12/09/2017               67                1             100.0
# 12/10/2017               78                1             100.0
# 12/11/2017              111                1             100.0
# 12/12/2017              153                1             100.0
# 12/13/2017              135                1             100.0
# 12/14/2017               72                1             100.0
# 12/15/2017               69                1             100.0
# 12/16/2017               64                1             100.0
# 12/17/2017               25                1             100.0
# 12/18/2017               49                1             100.0
# 12/19/2017               44                1             100.0
# 12/20/2017               43                1             100.0
# 12/21/2017               13                1             100.0
# 12/22/2017               36                1             100.0
# 12/23/2017               18                1             100.0
# 12/24/2017               30                1             100.0
# 12/25/2017               79                1             100.0
# 12/26/2017               78                1             100.0
# 12/27/2017               74                1             100.0
# 12/28/2017               76                1             100.0
# 12/29/2017               80                1             100.0
# 12/30/2017               38                1             100.0
# 12/31/2017               42                1             100.0
#
#             AQS_PARAMETER_CODE        AQS_PARAMETER_DESC  CBSA_CODE  \
# Date
# 01/05/2017               88101  PM2.5 - Local Conditions      41620
# 01/06/2017               88101  PM2.5 - Local Conditions      41620
# 01/07/2017               88101  PM2.5 - Local Conditions      41620
# 01/10/2017               88101  PM2.5 - Local Conditions      41620
# 01/11/2017               88101  PM2.5 - Local Conditions      41620
# 01/12/2017               88101  PM2.5 - Local Conditions      41620
# 01/13/2017               88101  PM2.5 - Local Conditions      41620
# 01/14/2017               88101  PM2.5 - Local Conditions      41620
# 01/15/2017               88101  PM2.5 - Local Conditions      41620
# 01/16/2017               88101  PM2.5 - Local Conditions      41620
# 01/17/2017               88101  PM2.5 - Local Conditions      41620
# 01/18/2017               88101  PM2.5 - Local Conditions      41620
# 01/19/2017               88101  PM2.5 - Local Conditions      41620
# 01/20/2017               88101  PM2.5 - Local Conditions      41620
# 01/21/2017               88101  PM2.5 - Local Conditions      41620
# 01/22/2017               88101  PM2.5 - Local Conditions      41620
# 01/23/2017               88101  PM2.5 - Local Conditions      41620
# 01/24/2017               88101  PM2.5 - Local Conditions      41620
# 01/25/2017               88101  PM2.5 - Local Conditions      41620
# 01/26/2017               88101  PM2.5 - Local Conditions      41620
# 01/27/2017               88101  PM2.5 - Local Conditions      41620
# 01/28/2017               88101  PM2.5 - Local Conditions      41620
# 01/29/2017               88101  PM2.5 - Local Conditions      41620
# 01/30/2017               88101  PM2.5 - Local Conditions      41620
# 01/31/2017               88101  PM2.5 - Local Conditions      41620
# 02/01/2017               88101  PM2.5 - Local Conditions      41620
# 02/02/2017               88101  PM2.5 - Local Conditions      41620
# 02/03/2017               88101  PM2.5 - Local Conditions      41620
# 02/04/2017               88101  PM2.5 - Local Conditions      41620
# 02/05/2017               88101  PM2.5 - Local Conditions      41620
# ...                        ...                       ...        ...
# 12/02/2017               88101  PM2.5 - Local Conditions      41620
# 12/03/2017               88101  PM2.5 - Local Conditions      41620
# 12/04/2017               88101  PM2.5 - Local Conditions      41620
# 12/05/2017               88101  PM2.5 - Local Conditions      41620
# 12/06/2017               88101  PM2.5 - Local Conditions      41620
# 12/07/2017               88101  PM2.5 - Local Conditions      41620
# 12/08/2017               88101  PM2.5 - Local Conditions      41620
# 12/09/2017               88101  PM2.5 - Local Conditions      41620
# 12/10/2017               88101  PM2.5 - Local Conditions      41620
# 12/11/2017               88101  PM2.5 - Local Conditions      41620
# 12/12/2017               88101  PM2.5 - Local Conditions      41620
# 12/13/2017               88101  PM2.5 - Local Conditions      41620
# 12/14/2017               88101  PM2.5 - Local Conditions      41620
# 12/15/2017               88101  PM2.5 - Local Conditions      41620
# 12/16/2017               88101  PM2.5 - Local Conditions      41620
# 12/17/2017               88101  PM2.5 - Local Conditions      41620
# 12/18/2017               88101  PM2.5 - Local Conditions      41620
# 12/19/2017               88101  PM2.5 - Local Conditions      41620
# 12/20/2017               88101  PM2.5 - Local Conditions      41620
# 12/21/2017               88101  PM2.5 - Local Conditions      41620
# 12/22/2017               88101  PM2.5 - Local Conditions      41620
# 12/23/2017               88101  PM2.5 - Local Conditions      41620
# 12/24/2017               88101  PM2.5 - Local Conditions      41620
# 12/25/2017               88101  PM2.5 - Local Conditions      41620
# 12/26/2017               88101  PM2.5 - Local Conditions      41620
# 12/27/2017               88101  PM2.5 - Local Conditions      41620
# 12/28/2017               88101  PM2.5 - Local Conditions      41620
# 12/29/2017               88101  PM2.5 - Local Conditions      41620
# 12/30/2017               88101  PM2.5 - Local Conditions      41620
# 12/31/2017               88101  PM2.5 - Local Conditions      41620
#
#                      CBSA_NAME  STATE_CODE STATE  COUNTY_CODE     COUNTY  \
# Date
# 01/05/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/06/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/07/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/10/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/11/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/12/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/13/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/14/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/15/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/16/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/17/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/18/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/19/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/20/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/21/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/22/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/23/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/24/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/25/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/26/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/27/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/28/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/29/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/30/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 01/31/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 02/01/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 02/02/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 02/03/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 02/04/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 02/05/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# ...                        ...         ...   ...          ...        ...
# 12/02/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/03/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/04/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/05/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/06/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/07/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/08/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/09/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/10/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/11/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/12/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/13/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/14/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/15/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/16/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/17/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/18/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/19/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/20/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/21/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/22/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/23/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/24/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/25/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/26/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/27/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/28/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/29/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/30/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
# 12/31/2017  Salt Lake City, UT          49  Utah           35  Salt Lake
#
#             SITE_LATITUDE  SITE_LONGITUDE
# Date
# 01/05/2017      40.736389     -111.872222
# 01/06/2017      40.736389     -111.872222
# 01/07/2017      40.736389     -111.872222
# 01/10/2017      40.736389     -111.872222
# 01/11/2017      40.736389     -111.872222
# 01/12/2017      40.736389     -111.872222
# 01/13/2017      40.736389     -111.872222
# 01/14/2017      40.736389     -111.872222
# 01/15/2017      40.736389     -111.872222
# 01/16/2017      40.736389     -111.872222
# 01/17/2017      40.736389     -111.872222
# 01/18/2017      40.736389     -111.872222
# 01/19/2017      40.736389     -111.872222
# 01/20/2017      40.736389     -111.872222
# 01/21/2017      40.736389     -111.872222
# 01/22/2017      40.736389     -111.872222
# 01/23/2017      40.736389     -111.872222
# 01/24/2017      40.736389     -111.872222
# 01/25/2017      40.736389     -111.872222
# 01/26/2017      40.736389     -111.872222
# 01/27/2017      40.736389     -111.872222
# 01/28/2017      40.736389     -111.872222
# 01/29/2017      40.736389     -111.872222
# 01/30/2017      40.736389     -111.872222
# 01/31/2017      40.736389     -111.872222
# 02/01/2017      40.736389     -111.872222
# 02/02/2017      40.736389     -111.872222
# 02/03/2017      40.736389     -111.872222
# 02/04/2017      40.736389     -111.872222
# 02/05/2017      40.736389     -111.872222
# ...                   ...             ...
# 12/02/2017      40.736389     -111.872222
# 12/03/2017      40.736389     -111.872222
# 12/04/2017      40.736389     -111.872222
# 12/05/2017      40.736389     -111.872222
# 12/06/2017      40.736389     -111.872222
# 12/07/2017      40.736389     -111.872222
# 12/08/2017      40.736389     -111.872222
# 12/09/2017      40.736389     -111.872222
# 12/10/2017      40.736389     -111.872222
# 12/11/2017      40.736389     -111.872222
# 12/12/2017      40.736389     -111.872222
# 12/13/2017      40.736389     -111.872222
# 12/14/2017      40.736389     -111.872222
# 12/15/2017      40.736389     -111.872222
# 12/16/2017      40.736389     -111.872222
# 12/17/2017      40.736389     -111.872222
# 12/18/2017      40.736389     -111.872222
# 12/19/2017      40.736389     -111.872222
# 12/20/2017      40.736389     -111.872222
# 12/21/2017      40.736389     -111.872222
# 12/22/2017      40.736389     -111.872222
# 12/23/2017      40.736389     -111.872222
# 12/24/2017      40.736389     -111.872222
# 12/25/2017      40.736389     -111.872222
# 12/26/2017      40.736389     -111.872222
# 12/27/2017      40.736389     -111.872222
# 12/28/2017      40.736389     -111.872222
# 12/29/2017      40.736389     -111.872222
# 12/30/2017      40.736389     -111.872222
# 12/31/2017      40.736389     -111.872222
#
# [1065 rows x 17 columns]

# %% [markdown]
# ### Task 1.3. Plot the data
#
# Plot the daily mean PM2.5 concentration and daily AQI value. Since there are multiple POCs for each day, plot the data in each of the following ways:
# 1. Average the daily mean PM2.5 concentration and daily AQI value over the POCs for each day. In a single figure, plot date vs. each of these two quantities.
# + Make two plots, one for daily mean PM2.5 concentration and the other for daily AQI value. In the first plot, plot the daily mean PM2.5 concentration for each POC value (POC=1,4,5) seperately. In the second plot, plot the daily AQI value for each POC value (POC=1,4,5) seperately.
#
# *Hint*: use the pandas groupby function

# %%
# your code goes here
mean_plot=data.groupby(['Date'])['Daily Mean PM2.5 Concentration', 'DAILY_AQI_VALUE'].mean()
mean_plot.plot()

#mean_PM=data['Daily Mean PM2.5 Concentration'].groupby(by= data['POC']).mean()
#mean_API=data['DAILY_AQI_VALUE'].groupby(by=data['POC']).mean()

# %%
a=data.groupby(['POC'], as_index=False)['Date','Daily Mean PM2.5 Concentration']
fig, ax = plt.subplots(figsize=(10,8))
a.plot(x='Date',ax=ax)   
L=plt.legend()
L.get_texts()[0].set_text('POC 1')
L.get_texts()[1].set_text('POC 4')
L.get_texts()[2].set_text('POC 5')

# %%
a=data.groupby(['POC'])['Date','DAILY_AQI_VALUE']
fig, ax = plt.subplots()
a.plot(x='Date',y=['DAILY_AQI_VALUE'],ax=ax) 
L=plt.legend()
L.get_texts()[0].set_text('POC 1')
L.get_texts()[1].set_text('POC 4')
L.get_texts()[2].set_text('POC 5')

# %% [markdown]
# ### Task 1.4. Plot a moving average
#
# Make a plot with both the daily AQI value and a moving average for the daily AQI value. Use the daily AQI value that is averaged over the POC. Experiment with different time windows to find one that is reasonable.
#
# *Hint:* Use the rolling() function as in Lecture 7.

# %%
# your code goes here
import numpy as np
mean_plot=data.groupby(['Date'])['DAILY_AQI_VALUE'].mean().reset_index()
#mean_plot.plot()
#d=data[['Date','DAILY_AQI_VALUE']]
mean_plot['Rolling_AQI'] = np.round(data['DAILY_AQI_VALUE'].rolling(window = 2, center = False).mean(), 2)
mean_plot.plot('Date')

# %% [markdown]
# ## Part 2: A/B testing
#
# First read the WIRED article on A/B testing [here](http://www.wired.com/2012/04/ff_abtesting/).
#
# Suppose your company is developing a new logo. The art department develops two logos: ‘Logo A’ and ‘Logo B’, shown below.
# ![](http://www.wired.com/wiredenterprise/wp-content/gallery/20-05/ff_abtesting_f.jpg)
# Your job is to figure out which logo is better.
#
#
# You decide to conduct the following experiment. You use Google ads to buy 2000 advertisements. In $N_A=1000$ of the ads (randomly chosen), you use Logo A and in the other $N_B=1000$ ads, you use Logo B. Then you see which logo attracts more clicks.
#
# It turns out that $n_A=500$ Logo A viewers click on the ad while $n_B=550$ Logo B viewers click on the ad. Obviously Logo B did better in this test, but is the difference *significant* enough to say that Logo B is better? Or, perhaps, Logo B just got lucky in this test?
#
# The goal of this exercise will be to conduct a two-proportion z-test to determine if Logo B is better. The steps will be similiar to those from Lecture 8 used for the 1954 Salk polio-vaccine experiment.

# %% [markdown]
# ### Task 2.1.  Formulate null hypothesis
#
# Let $p_A = n_A/N_A$ be the proportion of clicks on Logo A and similiarly $p_B$ be the proportion of clicks on Logo B. In terms of $p_A$ and $p_B$, clearly state the null and alternative hypothesis.

# %% [markdown]
# **Your Solution:** We will consider the Null hypothesis as the current conclusion that B is better than A is true. Null hypothesis $H_0$.
# $$
# H_0\colon p_A - p_B \leq 0
# $$
# and Alternative hypothesis as the result of the experiment are not true
# $$
# H_a\colon p_A - p_B >0,
# $$

# %% [markdown]
# ### Task 2.2.  Find the two-proportion z-value
#
# Assuming the null hypothesis, we know from lecture that the test statistic, called the *two-proportion z-value*,
# $$
# Z = \frac{p_A - p_B}{\sqrt{\hat{p} \hat{q} \left( \frac{1}{N_A} + \frac{1}{N_B} \right)}}.
# $$
# is approximately  distributed according to the standard normal distribution. Here $\hat{p} = \frac{N_A}{N_A + N_B}p_A + \frac{N_B}{N_A + N_B}p_B$ and $\hat{q} = 1-\hat{p}$.
#
#
# Find the two-proportion z-value.

# %%
# your code goes here
NA=1000
NB=1000
nA=500
nB=550
pA=nA/NA
pB=nB/NB
phat = NA*pA/(NA+NB) + NB*pB/(NA+NB)
qhat = 1-phat

z = (pA - pB)/sc.sqrt(phat*qhat*(1/NA + 1/NB)) 
print(z)
# Out:
# -2.2388683142

# %% [markdown]
# ### Task 2.3. Complete the two proportion z-test
#
# Find the $p$-value for the hypothesis test.

# %%
# your code goes here
p_value = 1-norm.cdf(z)
print(p_value)
# Out:
# 0.98741775715

# %% [markdown]
# ### Task 2.4. Interpretation
#
# Interpret the $p$-value in this example and  state the result of the hypothesis test at the $\alpha=5\%$ and $\alpha=1\%$ significance levels.

# %% [markdown]
# **Your Interpretation:** The probability that an erroneous conclusion is reached, under the assumption of the null hypothesis, is $98$ times, way more than the significance level,of both  $\alpha$. We accept the null hypothesis and declare that the B is more effective than a A!
